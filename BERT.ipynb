# %%
import pandas as pd
import nltk
import numpy as np
import re

#load inthe NTLK stopwords to remove articles, preposition and other words that are not actionable
from nltk.corpus import stopwords
# This allows to create individual objects from a bog of words
from nltk.tokenize import word_tokenize, sent_tokenize
# Lemmatizer helps to reduce words to the base form
from nltk.stem import WordNetLemmatizer

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
import os
os.chdir('/content/gdrive/My Drive/Deep Learning/Code')
df=pd.read_csv('summer-products-with-rating-and-performance_2020-08.csv')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# Mounted at /content/gdrive
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
label = [1 if sales > 300 else 0 for sales in df["units_sold"]]
df['high_sale'] = label

# Plotting with Seaborn
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='high_sale', palette=['blue', 'orange'])
plt.xlabel('High Sales')
plt.ylabel('Count')
plt.title('Count of High Sales (0s and 1s)')
plt.show()

# %%
from sklearn.utils import resample

# Separate majority and minority classes
df_majority = df[df['high_sale'] == 1]  # 900 rows
df_minority = df[df['high_sale'] == 0]  # 640 rows

# Upsample minority class
df_minority_upsampled = resample(df_minority,
                               replace=True,      # sample with replacement
                               n_samples=len(df_majority),  # match majority class
                               random_state=42)   # reproducible results

# Combine majority and upsampled minority
df_balanced = pd.concat([df_majority, df_minority_upsampled])

# Verify the balance
print("Original dataset shape:", df['high_sale'].value_counts())
print("\nBalanced dataset shape:", df_balanced['high_sale'].value_counts())

# Shuffle the dataset
df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)
# Out:
# Original dataset shape: high_sale
# 1    925
# 0    648
# Name: count, dtype: int64
#
# Balanced dataset shape: high_sale
# 1    925
# 0    925
# Name: count, dtype: int64

# %%
sns.countplot(data=df_balanced, x='high_sale', palette=['blue', 'orange'])
plt.xlabel('High Sales')
plt.ylabel('Count')
plt.title('Count of High Sales (0s and 1s)')
plt.show()

# %%
df_balanced = df_balanced[['high_sale', 'title_orig']]

# %%
def process_sentence(sentence):
    new_tokens = word_tokenize(sentence)
    new_tokens = [token.lower() for token in new_tokens]
    new_tokens =[token for token in new_tokens if token not in stopwords.words('english')]
    new_tokens = [token for token in new_tokens if token.isalpha()]
    lemmatizer = WordNetLemmatizer()
    new_tokens =[lemmatizer.lemmatize(token) for token in new_tokens]
    return " ".join(new_tokens)

# %%
titles = df_balanced['title_orig'].tolist()
tokens = [process_sentence(t) for t in titles]
df_balanced['title_preprocessed'] = tokens
df_balanced.head()
# Out:
#    high_sale                                         title_orig  \
# 0          1  Women Fashion Casual Summer Sleeveless Blackle...
# 1          0  Summer Fashion Women Sexy Lace Strap Shirt Top...
# 2          1  Woman's New Summer Women Stretchy Camisole  Sp...
# 3          1  Women Fashion Lace Party Cocktail Mini Dress L...
# 4          0  Women Summer Off Sholuder Round Neck Printed B...
#
#                                   title_preprocessed
# 0  woman fashion casual summer sleeveless blackle...
# 1  summer fashion woman sexy lace strap shirt top...
# 2  woman new summer woman stretchy camisole spagh...
# 3  woman fashion lace party cocktail mini dress l...
# 4  woman summer sholuder round neck printed big s...

# %%
df_balanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   high_sale           1850 non-null   int64
#  1   title_orig          1850 non-null   object
#  2   title_preprocessed  1850 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 43.5+ KB

# %%
from transformers import BertTokenizer, TFBertModel
# Initialize tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = TFBertModel.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
from transformers import BertTokenizer, TFBertModel
import tensorflow as tf
import numpy as np
import warnings

# Suppress warnings
warnings.filterwarnings('ignore')

# Initialize BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', from_pt=True)
bert_model = TFBertModel.from_pretrained('bert-base-uncased', from_pt=True)

def encode_texts(texts, max_length=128):
    inputs = tokenizer(
        texts.tolist(),
        max_length=max_length,
        padding='max_length',
        truncation=True,
        return_tensors="tf"
    )
    return inputs

def get_bert_embeddings(encoded_inputs):
    outputs = bert_model(encoded_inputs['input_ids'],
                        attention_mask=encoded_inputs['attention_mask'])
    return outputs.last_hidden_state[:, 0, :]

def process_in_batches(df, batch_size=32):
    """Process text data in batches to avoid memory issues"""
    all_embeddings = []

    # Calculate number of batches
    n_samples = len(df)
    n_batches = (n_samples + batch_size - 1) // batch_size

    for i in range(n_batches):
        start_idx = i * batch_size
        end_idx = min((i + 1) * batch_size, n_samples)

        # Get batch of texts
        batch_texts = df['title_preprocessed'].iloc[start_idx:end_idx]

        # Process batch
        batch_encodings = encode_texts(batch_texts)
        batch_embeddings = get_bert_embeddings(batch_encodings)

        # Convert to numpy and store
        all_embeddings.append(batch_embeddings.numpy())

        # Optional: Print progress
        print(f"Processed batch {i+1}/{n_batches}", end='\r')

    # Combine all batches
    final_embeddings = np.vstack(all_embeddings)
    print("\nProcessing complete!")
    return final_embeddings

# Process data in batches
bert_embeddings_np = process_in_batches(df_balanced, batch_size=32)

print("BERT embeddings shape:", bert_embeddings_np.shape)

# Add embeddings as features
for i in range(bert_embeddings_np.shape[1]):
    df_balanced[f'bert_feature_{i}'] = bert_embeddings_np[:, i]
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Processed batch 58/58
# Processing complete!
# BERT embeddings shape: (1850, 768)

# %%
df_balanced.head()
# Out:
#    high_sale                                         title_orig  \
# 0          1  Women Fashion Casual Summer Sleeveless Blackle...
# 1          0  Summer Fashion Women Sexy Lace Strap Shirt Top...
# 2          1  Woman's New Summer Women Stretchy Camisole  Sp...
# 3          1  Women Fashion Lace Party Cocktail Mini Dress L...
# 4          0  Women Summer Off Sholuder Round Neck Printed B...
#
#                                   title_preprocessed  bert_feature_0  \
# 0  woman fashion casual summer sleeveless blackle...        0.001005
# 1  summer fashion woman sexy lace strap shirt top...       -0.105362
# 2  woman new summer woman stretchy camisole spagh...       -0.048788
# 3  woman fashion lace party cocktail mini dress l...       -0.134902
# 4  woman summer sholuder round neck printed big s...       -0.146917
#
#    bert_feature_1  bert_feature_2  bert_feature_3  bert_feature_4  \
# 0       -0.533275       -0.534818        0.156759        0.073843
# 1       -0.345659       -0.226914        0.226847        0.053992
# 2       -0.846473       -0.265181        0.217692        0.046021
# 3       -0.363934        0.069911        0.314845       -0.003409
# 4       -0.475034       -0.028959        0.103094        0.175031
#
#    bert_feature_5  bert_feature_6  ...  bert_feature_758  bert_feature_759  \
# 0       -0.061246        0.418828  ...         -0.009219         -0.727769
# 1        0.015522        0.443834  ...         -0.013285         -0.728474
# 2       -0.087229        0.363559  ...          0.039934         -0.585656
# 3        0.077615        0.735594  ...         -0.050925         -0.711547
# 4       -0.036770        0.392105  ...         -0.171903         -0.705456
#
#    bert_feature_760  bert_feature_761  bert_feature_762  bert_feature_763  \
# 0          0.371944         -0.085761          0.138729         -0.245404
# 1          0.332205          0.045897          0.000037         -0.168964
# 2          0.217908         -0.125180          0.248969         -0.192281
# 3          0.259914          0.183044          0.213245         -0.284517
# 4          0.122383          0.211105          0.325868         -0.171740
#
#    bert_feature_764  bert_feature_765  bert_feature_766  bert_feature_767
# 0         -0.088360         -0.366857          0.028042         -0.036503
# 1         -0.067307         -0.257121          0.112011         -0.103263
# 2          0.001998         -0.244936         -0.147212          0.137787
# 3          0.154202         -0.275265         -0.189102         -0.130316
# 4         -0.095418         -0.317080         -0.116700         -0.094603
#
# [5 rows x 771 columns]

# %%
df_balanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Columns: 771 entries, high_sale to bert_feature_767
# dtypes: float32(768), int64(1), object(2)
# memory usage: 5.5+ MB

# %%
X = df_balanced.loc[:, ~df_balanced.columns.isin(['high_sale', 'title_orig', 'title_preprocessed'])]
y = df_balanced['high_sale']

# %%
# Verify shapes
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (1850, 768)
# y shape: (1850,)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Concatenate, LSTM, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.125, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.14286, random_state=42)

# %%
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of val examples = " + str(X_val.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(y_train.shape))
print ("X_val shape: " + str(X_val.shape))
print ("Y_val shape: " + str(y_val.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(y_test.shape))
# Out:
# number of training examples = 1386
# number of val examples = 232
# number of test examples = 232
# X_train shape: (1386, 768)
# Y_train shape: (1386,)
# X_val shape: (232, 768)
# Y_val shape: (232,)
# X_test shape: (232, 768)
# Y_test shape: (232,)

# %%
# Defining hold out data for evaluation
X_train = tf.expand_dims(X_train, axis=-1)
#input_shape = X_train.shape[1:]

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Sequential

# Define model
model = Sequential([
    # First dense layer
    Dense(256, activation='relu',
          kernel_regularizer=l2(0.01),
          input_shape=(768,)),
    BatchNormalization(),
    Dropout(0.3),

    # Second dense layer
    Dense(128, activation='relu',
          kernel_regularizer=l2(0.01)),
    BatchNormalization(),
    Dropout(0.3),

    # Output layer
    Dense(1, activation='sigmoid')
])

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
optimizer = Adam(learning_rate=1e-4)
model.compile(optimizer=optimizer,
             loss='binary_crossentropy',
             metrics=['accuracy'])

# %%
# Define callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
        min_delta=0.001
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.1,
        patience=3,
        min_lr=1e-6
    )
]

# Train model
history = model.fit(
    X, y,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 90ms/step - accuracy: 0.5007 - loss: 6.4345 - val_accuracy: 0.5378 - val_loss: 6.0383 - learning_rate: 1.0000e-04
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5830 - loss: 6.0521 - val_accuracy: 0.5351 - val_loss: 5.8259 - learning_rate: 1.0000e-04
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5721 - loss: 5.8658 - val_accuracy: 0.5459 - val_loss: 5.6193 - learning_rate: 1.0000e-04
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6175 - loss: 5.6072 - val_accuracy: 0.6081 - val_loss: 5.4348 - learning_rate: 1.0000e-04
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6247 - loss: 5.4242 - val_accuracy: 0.6027 - val_loss: 5.2734 - learning_rate: 1.0000e-04
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6626 - loss: 5.2471 - val_accuracy: 0.6432 - val_loss: 5.1131 - learning_rate: 1.0000e-04
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6555 - loss: 5.1112 - val_accuracy: 0.6865 - val_loss: 4.9712 - learning_rate: 1.0000e-04
# Epoch 8/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6517 - loss: 4.9600 - val_accuracy: 0.7027 - val_loss: 4.8358 - learning_rate: 1.0000e-04
# Epoch 9/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6829 - loss: 4.8143 - val_accuracy: 0.7000 - val_loss: 4.7306 - learning_rate: 1.0000e-04
# Epoch 10/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7139 - loss: 4.6742 - val_accuracy: 0.7081 - val_loss: 4.6166 - learning_rate: 1.0000e-04
# Epoch 11/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7093 - loss: 4.5834 - val_accuracy: 0.7081 - val_loss: 4.4953 - learning_rate: 1.0000e-04
# Epoch 12/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7167 - loss: 4.4568 - val_accuracy: 0.7162 - val_loss: 4.4068 - learning_rate: 1.0000e-04
# Epoch 13/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7294 - loss: 4.3612 - val_accuracy: 0.6973 - val_loss: 4.3063 - learning_rate: 1.0000e-04
# Epoch 14/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7256 - loss: 4.2719 - val_accuracy: 0.7027 - val_loss: 4.2522 - learning_rate: 1.0000e-04
# Epoch 15/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7516 - loss: 4.1509 - val_accuracy: 0.7243 - val_loss: 4.1379 - learning_rate: 1.0000e-04
# Epoch 16/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7268 - loss: 4.0778 - val_accuracy: 0.7189 - val_loss: 4.0705 - learning_rate: 1.0000e-04
# Epoch 17/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7448 - loss: 3.9936 - val_accuracy: 0.7270 - val_loss: 3.9623 - learning_rate: 1.0000e-04
# Epoch 18/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7643 - loss: 3.8950 - val_accuracy: 0.7378 - val_loss: 3.8969 - learning_rate: 1.0000e-04
# Epoch 19/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7365 - loss: 3.8410 - val_accuracy: 0.7405 - val_loss: 3.8289 - learning_rate: 1.0000e-04
# Epoch 20/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7596 - loss: 3.7519 - val_accuracy: 0.7081 - val_loss: 3.7948 - learning_rate: 1.0000e-04
# Epoch 21/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7533 - loss: 3.6929 - val_accuracy: 0.7378 - val_loss: 3.6996 - learning_rate: 1.0000e-04
# Epoch 22/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8169 - loss: 3.5802 - val_accuracy: 0.7757 - val_loss: 3.6016 - learning_rate: 1.0000e-04
# Epoch 23/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7733 - loss: 3.5603 - val_accuracy: 0.7514 - val_loss: 3.5443 - learning_rate: 1.0000e-04
# Epoch 24/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7868 - loss: 3.4864 - val_accuracy: 0.7432 - val_loss: 3.5131 - learning_rate: 1.0000e-04
# Epoch 25/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7793 - loss: 3.4282 - val_accuracy: 0.7405 - val_loss: 3.4742 - learning_rate: 1.0000e-04
# Epoch 26/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7915 - loss: 3.3372 - val_accuracy: 0.7432 - val_loss: 3.3794 - learning_rate: 1.0000e-04
# Epoch 27/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7964 - loss: 3.2992 - val_accuracy: 0.7270 - val_loss: 3.3399 - learning_rate: 1.0000e-04
# Epoch 28/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7790 - loss: 3.2535 - val_accuracy: 0.7514 - val_loss: 3.2944 - learning_rate: 1.0000e-04
# Epoch 29/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7915 - loss: 3.1895 - val_accuracy: 0.7595 - val_loss: 3.2154 - learning_rate: 1.0000e-04
# Epoch 30/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8093 - loss: 3.1038 - val_accuracy: 0.7595 - val_loss: 3.1677 - learning_rate: 1.0000e-04
# Epoch 31/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7971 - loss: 3.0960 - val_accuracy: 0.7622 - val_loss: 3.1115 - learning_rate: 1.0000e-04
# Epoch 32/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8222 - loss: 2.9871 - val_accuracy: 0.7432 - val_loss: 3.1006 - learning_rate: 1.0000e-04
# Epoch 33/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8267 - loss: 2.9367 - val_accuracy: 0.7730 - val_loss: 3.0299 - learning_rate: 1.0000e-04
# Epoch 34/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8152 - loss: 2.8772 - val_accuracy: 0.7514 - val_loss: 3.0108 - learning_rate: 1.0000e-04
# Epoch 35/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8177 - loss: 2.8544 - val_accuracy: 0.7568 - val_loss: 2.9606 - learning_rate: 1.0000e-04
# Epoch 36/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8377 - loss: 2.7930 - val_accuracy: 0.7378 - val_loss: 2.9311 - learning_rate: 1.0000e-04
# Epoch 37/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8035 - loss: 2.7766 - val_accuracy: 0.7486 - val_loss: 2.9103 - learning_rate: 1.0000e-04
# Epoch 38/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8377 - loss: 2.7018 - val_accuracy: 0.7838 - val_loss: 2.7806 - learning_rate: 1.0000e-04
# Epoch 39/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8511 - loss: 2.6539 - val_accuracy: 0.7514 - val_loss: 2.7683 - learning_rate: 1.0000e-04
# Epoch 40/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8249 - loss: 2.6481 - val_accuracy: 0.7622 - val_loss: 2.7513 - learning_rate: 1.0000e-04
# Epoch 41/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8299 - loss: 2.5783 - val_accuracy: 0.7459 - val_loss: 2.7206 - learning_rate: 1.0000e-04
# Epoch 42/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8537 - loss: 2.5052 - val_accuracy: 0.7811 - val_loss: 2.6311 - learning_rate: 1.0000e-04
# Epoch 43/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8329 - loss: 2.4813 - val_accuracy: 0.7892 - val_loss: 2.6246 - learning_rate: 1.0000e-04
# Epoch 44/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8414 - loss: 2.4599 - val_accuracy: 0.7649 - val_loss: 2.5799 - learning_rate: 1.0000e-04
# Epoch 45/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8360 - loss: 2.4169 - val_accuracy: 0.7811 - val_loss: 2.5670 - learning_rate: 1.0000e-04
# Epoch 46/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8641 - loss: 2.3567 - val_accuracy: 0.7730 - val_loss: 2.5669 - learning_rate: 1.0000e-04
# Epoch 47/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8706 - loss: 2.3189 - val_accuracy: 0.7919 - val_loss: 2.4848 - learning_rate: 1.0000e-04
# Epoch 48/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8508 - loss: 2.2886 - val_accuracy: 0.7757 - val_loss: 2.4595 - learning_rate: 1.0000e-04
# Epoch 49/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8744 - loss: 2.2385 - val_accuracy: 0.7838 - val_loss: 2.4301 - learning_rate: 1.0000e-04
# Epoch 50/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8589 - loss: 2.2319 - val_accuracy: 0.7811 - val_loss: 2.4020 - learning_rate: 1.0000e-04
# Epoch 51/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8508 - loss: 2.1997 - val_accuracy: 0.7676 - val_loss: 2.3791 - learning_rate: 1.0000e-04
# Epoch 52/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8556 - loss: 2.1536 - val_accuracy: 0.7784 - val_loss: 2.3540 - learning_rate: 1.0000e-04
# Epoch 53/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8752 - loss: 2.1088 - val_accuracy: 0.7784 - val_loss: 2.2916 - learning_rate: 1.0000e-04
# Epoch 54/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8553 - loss: 2.0977 - val_accuracy: 0.7730 - val_loss: 2.2820 - learning_rate: 1.0000e-04
# Epoch 55/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8830 - loss: 2.0574 - val_accuracy: 0.7703 - val_loss: 2.3064 - learning_rate: 1.0000e-04
# Epoch 56/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8862 - loss: 2.0162 - val_accuracy: 0.7757 - val_loss: 2.2106 - learning_rate: 1.0000e-04
# Epoch 57/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8667 - loss: 1.9904 - val_accuracy: 0.7730 - val_loss: 2.1977 - learning_rate: 1.0000e-04
# Epoch 58/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8718 - loss: 1.9877 - val_accuracy: 0.7486 - val_loss: 2.2116 - learning_rate: 1.0000e-04
# Epoch 59/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8590 - loss: 1.9496 - val_accuracy: 0.7676 - val_loss: 2.1525 - learning_rate: 1.0000e-04
# Epoch 60/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8884 - loss: 1.8943 - val_accuracy: 0.7703 - val_loss: 2.1271 - learning_rate: 1.0000e-04
# Epoch 61/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8903 - loss: 1.8777 - val_accuracy: 0.7649 - val_loss: 2.1596 - learning_rate: 1.0000e-04
# Epoch 62/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8702 - loss: 1.8707 - val_accuracy: 0.7946 - val_loss: 2.0959 - learning_rate: 1.0000e-04
# Epoch 63/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8627 - loss: 1.8320 - val_accuracy: 0.7973 - val_loss: 2.0351 - learning_rate: 1.0000e-04
# Epoch 64/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8685 - loss: 1.8293 - val_accuracy: 0.7811 - val_loss: 2.0162 - learning_rate: 1.0000e-04
# Epoch 65/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8742 - loss: 1.8057 - val_accuracy: 0.7811 - val_loss: 2.0252 - learning_rate: 1.0000e-04
# Epoch 66/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8739 - loss: 1.7954 - val_accuracy: 0.7811 - val_loss: 2.0107 - learning_rate: 1.0000e-04
# Epoch 67/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8808 - loss: 1.7279 - val_accuracy: 0.7784 - val_loss: 2.0005 - learning_rate: 1.0000e-04
# Epoch 68/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8669 - loss: 1.7320 - val_accuracy: 0.7892 - val_loss: 1.9304 - learning_rate: 1.0000e-04
# Epoch 69/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8738 - loss: 1.7139 - val_accuracy: 0.7730 - val_loss: 1.9656 - learning_rate: 1.0000e-04
# Epoch 70/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8915 - loss: 1.6634 - val_accuracy: 0.7757 - val_loss: 1.9473 - learning_rate: 1.0000e-04
# Epoch 71/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8826 - loss: 1.6323 - val_accuracy: 0.8081 - val_loss: 1.8885 - learning_rate: 1.0000e-04
# Epoch 72/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8914 - loss: 1.6212 - val_accuracy: 0.7892 - val_loss: 1.8704 - learning_rate: 1.0000e-04
# Epoch 73/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8877 - loss: 1.5977 - val_accuracy: 0.7892 - val_loss: 1.8573 - learning_rate: 1.0000e-04
# Epoch 74/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8791 - loss: 1.5767 - val_accuracy: 0.7919 - val_loss: 1.8079 - learning_rate: 1.0000e-04
# Epoch 75/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8738 - loss: 1.5725 - val_accuracy: 0.8027 - val_loss: 1.7590 - learning_rate: 1.0000e-04
# Epoch 76/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9013 - loss: 1.5189 - val_accuracy: 0.8162 - val_loss: 1.7529 - learning_rate: 1.0000e-04
# Epoch 77/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9026 - loss: 1.5000 - val_accuracy: 0.7946 - val_loss: 1.7652 - learning_rate: 1.0000e-04
# Epoch 78/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9077 - loss: 1.4757 - val_accuracy: 0.8000 - val_loss: 1.7698 - learning_rate: 1.0000e-04
# Epoch 79/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8967 - loss: 1.4698 - val_accuracy: 0.7784 - val_loss: 1.7623 - learning_rate: 1.0000e-04
# Epoch 80/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9029 - loss: 1.4286 - val_accuracy: 0.8162 - val_loss: 1.7082 - learning_rate: 1.0000e-05
# Epoch 81/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9030 - loss: 1.4437 - val_accuracy: 0.8216 - val_loss: 1.7029 - learning_rate: 1.0000e-05
# Epoch 82/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8914 - loss: 1.4553 - val_accuracy: 0.8189 - val_loss: 1.7082 - learning_rate: 1.0000e-05
# Epoch 83/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9055 - loss: 1.4204 - val_accuracy: 0.8108 - val_loss: 1.7110 - learning_rate: 1.0000e-05
# Epoch 84/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9217 - loss: 1.4030 - val_accuracy: 0.8081 - val_loss: 1.7105 - learning_rate: 1.0000e-05
# Epoch 85/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9126 - loss: 1.3998 - val_accuracy: 0.8081 - val_loss: 1.7109 - learning_rate: 1.0000e-06
# Epoch 86/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8978 - loss: 1.4320 - val_accuracy: 0.8000 - val_loss: 1.7122 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])  # Change 'validation_accuracy' to 'val_accuracy'
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
