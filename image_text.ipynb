# %%
import pandas as pd
import nltk
import numpy as np
import re

#load inthe NTLK stopwords to remove articles, preposition and other words that are not actionable
from nltk.corpus import stopwords
# This allows to create individual objects from a bog of words
from nltk.tokenize import word_tokenize, sent_tokenize
# Lemmatizer helps to reduce words to the base form
from nltk.stem import WordNetLemmatizer

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
import os
os.chdir('/content/gdrive/My Drive/Deep Learning/Code')

import pandas as pd
import numpy as np
df_pickle = pd.read_pickle('image_sale.pkl')
# Out:
# Mounted at /content/gdrive

# %%
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df_pickle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   image_pixel  1338 non-null   object
#  1   high_sale    1338 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 21.0+ KB

# %%
df=pd.read_csv('summer-products-with-rating-and-performance_2020-08.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
#  12  rating_two_count              1528 non-null   float64
#  13  rating_one_count              1528 non-null   float64
#  14  badges_count                  1573 non-null   int64
#  15  badge_local_product           1573 non-null   int64
#  16  badge_product_quality         1573 non-null   int64
#  17  badge_fast_shipping           1573 non-null   int64
#  18  tags                          1573 non-null   object
#  19  product_color                 1532 non-null   object
#  20  product_variation_size_id     1559 non-null   object
#  21  product_variation_inventory   1573 non-null   int64
#  22  shipping_option_name          1573 non-null   object
#  23  shipping_option_price         1573 non-null   int64
#  24  shipping_is_express           1573 non-null   int64
#  25  countries_shipped_to          1573 non-null   int64
#  26  inventory_total               1573 non-null   int64
#  27  has_urgency_banner            473 non-null    float64
#  28  urgency_text                  473 non-null    object
#  29  origin_country                1556 non-null   object
#  30  merchant_title                1573 non-null   object
#  31  merchant_name                 1569 non-null   object
#  32  merchant_info_subtitle        1572 non-null   object
#  33  merchant_rating_count         1573 non-null   int64
#  34  merchant_rating               1573 non-null   float64
#  35  merchant_id                   1573 non-null   object
#  36  merchant_has_profile_picture  1573 non-null   int64
#  37  merchant_profile_picture      226 non-null    object
#  38  product_url                   1573 non-null   object
#  39  product_picture               1573 non-null   object
#  40  product_id                    1573 non-null   object
#  41  theme                         1573 non-null   object
#  42  crawl_month                   1573 non-null   object
# dtypes: float64(9), int64(15), object(19)
# memory usage: 528.6+ KB

# %%
index_list = [0, 4, 10, 22, 24, 37, 43, 50, 52, 53, 62, 77, 78, 85, 96, 97, 100, 111, 116, 134, 146, 148, 159, 165, 172, 176, 177, 188, 191, 197, 208, 210, 213, 232, 244, 246, 249, 251, 252, 255, 288, 291, 292, 298, 302, 305, 306, 310, 318, 324, 327, 329, 331, 341, 347, 350, 362, 375, 387, 388, 393, 397, 398, 411, 438, 439, 456, 467, 479, 484, 494, 495, 518, 519, 523, 538, 540, 548, 549, 550, 557, 558, 574, 590, 614, 615, 625, 635, 636, 637, 644, 647, 652, 659, 666, 673, 687, 689, 696, 699, 703, 709, 716, 739, 743, 750, 755, 757, 763, 783, 785, 789, 801, 816, 817, 826, 829, 836, 840, 844, 858, 868, 871, 884, 891, 892, 894, 902, 906, 913, 916, 923, 935, 937, 938, 945, 950, 953, 958, 970, 977, 979, 980, 982, 986, 991, 993, 995, 1003, 1008, 1017, 1026, 1044, 1065, 1069, 1073, 1078, 1083, 1086, 1096, 1108, 1115, 1124, 1129, 1130, 1138, 1143, 1152, 1182, 1186, 1209, 1228, 1230, 1248, 1250, 1261, 1271, 1276, 1279, 1283, 1294, 1311, 1312, 1323, 1326, 1328, 1330, 1343, 1352, 1353, 1361, 1362, 1366, 1368, 1371, 1374, 1380, 1384, 1386, 1390, 1395, 1403, 1417, 1419, 1422, 1428, 1429, 1435, 1437, 1441, 1444, 1456, 1460, 1464, 1471, 1472, 1474, 1477, 1480, 1488, 1491, 1494, 1495, 1516, 1523, 1537, 1541, 1542, 1558, 1559, 1560, 1564, 1568, 1569, 1570]
df = df.drop(index_list)

# Reset the index after dropping rows
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1338 non-null   object
#  1   title_orig                    1338 non-null   object
#  2   price                         1338 non-null   float64
#  3   retail_price                  1338 non-null   int64
#  4   currency_buyer                1338 non-null   object
#  5   units_sold                    1338 non-null   int64
#  6   uses_ad_boosts                1338 non-null   int64
#  7   rating                        1338 non-null   float64
#  8   rating_count                  1338 non-null   int64
#  9   rating_five_count             1297 non-null   float64
#  10  rating_four_count             1297 non-null   float64
#  11  rating_three_count            1297 non-null   float64
#  12  rating_two_count              1297 non-null   float64
#  13  rating_one_count              1297 non-null   float64
#  14  badges_count                  1338 non-null   int64
#  15  badge_local_product           1338 non-null   int64
#  16  badge_product_quality         1338 non-null   int64
#  17  badge_fast_shipping           1338 non-null   int64
#  18  tags                          1338 non-null   object
#  19  product_color                 1302 non-null   object
#  20  product_variation_size_id     1327 non-null   object
#  21  product_variation_inventory   1338 non-null   int64
#  22  shipping_option_name          1338 non-null   object
#  23  shipping_option_price         1338 non-null   int64
#  24  shipping_is_express           1338 non-null   int64
#  25  countries_shipped_to          1338 non-null   int64
#  26  inventory_total               1338 non-null   int64
#  27  has_urgency_banner            404 non-null    float64
#  28  urgency_text                  404 non-null    object
#  29  origin_country                1321 non-null   object
#  30  merchant_title                1338 non-null   object
#  31  merchant_name                 1334 non-null   object
#  32  merchant_info_subtitle        1338 non-null   object
#  33  merchant_rating_count         1338 non-null   int64
#  34  merchant_rating               1338 non-null   float64
#  35  merchant_id                   1338 non-null   object
#  36  merchant_has_profile_picture  1338 non-null   int64
#  37  merchant_profile_picture      209 non-null    object
#  38  product_url                   1338 non-null   object
#  39  product_picture               1338 non-null   object
#  40  product_id                    1338 non-null   object
#  41  theme                         1338 non-null   object
#  42  crawl_month                   1338 non-null   object
# dtypes: float64(9), int64(15), object(19)
# memory usage: 449.6+ KB

# %%
df.head()
# Out:
#                                                title  \
# 0  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 1  2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 2  Hot Summer Cool T-shirt pour les femmes Mode T...
# 3  Plus la taille d'été femmes décontracté sans m...
# 4  Women Fashion Loose Lace Blouse Blouse V Neck ...
#
#                                           title_orig  price  retail_price  \
# 0   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 1  2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 2  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 3  Plus Size Summer Women Casual Sleeveless Rompe...   3.92             9
# 4  Women Fashion Loose Lace Blouse V Neck Bat Sle...   7.00             6
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR       20000               1    3.45          6135
# 1            EUR         100               0    3.57            14
# 2            EUR        5000               1    4.03           579
# 3            EUR          10               0    5.00             1
# 4            EUR       50000               0    3.84          6742
#
#    rating_five_count  ...  merchant_rating_count  merchant_rating  \
# 0             2269.0  ...                  17752         3.899673
# 1                5.0  ...                    295         3.989831
# 2              295.0  ...                  23832         4.020435
# 3                1.0  ...                     65         3.507692
# 4             3172.0  ...                  10194         4.076516
#
#                 merchant_id  merchant_has_profile_picture  \
# 0  56458aa03a698c35c9050988                             0
# 1  5d464a1ffdf7bc44ee933c65                             0
# 2  58cfdefdacb37b556efdff7c                             0
# 3  5e4b9c3801ba9d210036fc5a                             0
# 4  5652f4053a698c76dc9a3f37                             1
#
#                             merchant_profile_picture  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://s3-us-west-1.amazonaws.com/sweeper-pro...
#
#                                        product_url  \
# 0  https://www.wish.com/c/58940d436a0d3d5da4e95a38
# 1  https://www.wish.com/c/5ea10e2c617580260d55310a
# 2  https://www.wish.com/c/5cedf17ad1d44c52c59e4aca
# 3  https://www.wish.com/c/5ec645bafd107a02279c8c54
# 4  https://www.wish.com/c/5c63a337d5e2ce4bbb3152cf
#
#                                      product_picture  \
# 0  https://contestimg.wish.com/api/webimage/58940...
# 1  https://contestimg.wish.com/api/webimage/5ea10...
# 2  https://contestimg.wish.com/api/webimage/5cedf...
# 3  https://contestimg.wish.com/api/webimage/5ec64...
# 4  https://contestimg.wish.com/api/webimage/5c63a...
#
#                  product_id   theme crawl_month
# 0  58940d436a0d3d5da4e95a38  summer     2020-08
# 1  5ea10e2c617580260d55310a  summer     2020-08
# 2  5cedf17ad1d44c52c59e4aca  summer     2020-08
# 3  5ec645bafd107a02279c8c54  summer     2020-08
# 4  5c63a337d5e2ce4bbb3152cf  summer     2020-08
#
# [5 rows x 43 columns]

# %%
# Concatenate the DataFrames horizontally
df = pd.concat([df, df_pickle], axis=1)

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 45 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1338 non-null   object
#  1   title_orig                    1338 non-null   object
#  2   price                         1338 non-null   float64
#  3   retail_price                  1338 non-null   int64
#  4   currency_buyer                1338 non-null   object
#  5   units_sold                    1338 non-null   int64
#  6   uses_ad_boosts                1338 non-null   int64
#  7   rating                        1338 non-null   float64
#  8   rating_count                  1338 non-null   int64
#  9   rating_five_count             1297 non-null   float64
#  10  rating_four_count             1297 non-null   float64
#  11  rating_three_count            1297 non-null   float64
#  12  rating_two_count              1297 non-null   float64
#  13  rating_one_count              1297 non-null   float64
#  14  badges_count                  1338 non-null   int64
#  15  badge_local_product           1338 non-null   int64
#  16  badge_product_quality         1338 non-null   int64
#  17  badge_fast_shipping           1338 non-null   int64
#  18  tags                          1338 non-null   object
#  19  product_color                 1302 non-null   object
#  20  product_variation_size_id     1327 non-null   object
#  21  product_variation_inventory   1338 non-null   int64
#  22  shipping_option_name          1338 non-null   object
#  23  shipping_option_price         1338 non-null   int64
#  24  shipping_is_express           1338 non-null   int64
#  25  countries_shipped_to          1338 non-null   int64
#  26  inventory_total               1338 non-null   int64
#  27  has_urgency_banner            404 non-null    float64
#  28  urgency_text                  404 non-null    object
#  29  origin_country                1321 non-null   object
#  30  merchant_title                1338 non-null   object
#  31  merchant_name                 1334 non-null   object
#  32  merchant_info_subtitle        1338 non-null   object
#  33  merchant_rating_count         1338 non-null   int64
#  34  merchant_rating               1338 non-null   float64
#  35  merchant_id                   1338 non-null   object
#  36  merchant_has_profile_picture  1338 non-null   int64
#  37  merchant_profile_picture      209 non-null    object
#  38  product_url                   1338 non-null   object
#  39  product_picture               1338 non-null   object
#  40  product_id                    1338 non-null   object
#  41  theme                         1338 non-null   object
#  42  crawl_month                   1338 non-null   object
#  43  image_pixel                   1338 non-null   object
#  44  high_sale                     1338 non-null   int64
# dtypes: float64(9), int64(16), object(20)
# memory usage: 470.5+ KB

# %%
# Plotting with Seaborn
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='high_sale', palette=['blue', 'orange'])
plt.xlabel('High Sales')
plt.ylabel('Count')
plt.title('Count of High Sales (0s and 1s)')
plt.show()
# Out:
# <ipython-input-12-8025e9c6e938>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='high_sale', palette=['blue', 'orange'])

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import resample

def balance_dataset(df, image_column='image_pixel'):
    """
    Balance dataset using image augmentation for images and upsampling for other features

    Args:
        df: DataFrame with image_pixel and other columns
        image_column: name of the column containing image data

    Returns:
        Balanced DataFrame
    """
    # Separate image data and other features
    X_images = np.stack(df[image_column].values)
    y = df['high_sale'].values

    # Balance images using augmentation
    X_images_balanced, y_balanced = augment_minority(X_images, y)

    # Create temporary dataframe without image column
    df_temp = df.drop(columns=[image_column])

    # Separate majority and minority classes for other features
    df_majority = df_temp[df_temp['high_sale'] == 1]
    df_minority = df_temp[df_temp['high_sale'] == 0]

    # Upsample minority class
    df_minority_upsampled = resample(df_minority,
                                   replace=True,
                                   n_samples=len(df_majority),
                                   random_state=42)

    # Combine majority and upsampled minority
    df_numeric_balanced = pd.concat([df_majority, df_minority_upsampled])

    # Create new balanced DataFrame
    df_final = df_numeric_balanced.copy()

    # Add balanced image data
    df_final[image_column] = [img for img in X_images_balanced]

    # Shuffle the dataset
    df_final = df_final.sample(frac=1, random_state=42).reset_index(drop=True)

    return df_final

def augment_minority(X, y):
    """
    Oversample minority class using image augmentation
    """
    datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest'
    )

    # Find minority class
    minority_class = 0 if np.sum(y == 0) < np.sum(y == 1) else 1
    majority_class = 1 - minority_class

    # Get minority samples
    X_minority = X[y == minority_class]
    y_minority = y[y == minority_class]

    # Calculate samples needed
    n_minority = len(X_minority)
    n_majority = np.sum(y == majority_class)
    n_to_generate = n_majority - n_minority

    # Generate augmented images
    X_augmented = []
    for i in range(n_to_generate):
        idx = i % n_minority
        img = X_minority[idx:idx+1]
        augmented = next(datagen.flow(img, batch_size=1))[0]
        X_augmented.append(augmented)

    # Combine original and augmented data
    X_balanced = np.concatenate([X, np.array(X_augmented)])
    y_balanced = np.concatenate([y, np.full(n_to_generate, minority_class)])

    return X_balanced, y_balanced

# Usage
print("Original dataset shape:", df['high_sale'].value_counts())

# Balance the dataset
df_balanced = balance_dataset(df)

print("\nBalanced dataset shape:", df_balanced['high_sale'].value_counts())

# Verify image shapes
print("\nImage shapes in balanced dataset:")
print("First image shape:", np.stack(df_balanced['image_pixel'].iloc[0]).shape)
# Out:
# Original dataset shape: high_sale
# 1    791
# 0    547
# Name: count, dtype: int64
#
# Balanced dataset shape: high_sale
# 0    791
# 1    791
# Name: count, dtype: int64
#
# Image shapes in balanced dataset:
# First image shape: (224, 224, 3)

# %%
df_balanced = balance_dataset(df, image_column='image_pixel')

# Verify the balance
print("Class distribution:", df_balanced['high_sale'].value_counts())

# Access balanced data
X_images = np.stack(df_balanced['image_pixel'].values)
X_numeric = df_balanced.drop(columns=['image_pixel', 'high_sale']).values
y = df_balanced['high_sale'].values
# Out:
# Class distribution: high_sale
# 0    791
# 1    791
# Name: count, dtype: int64

# %%
# Plotting with Seaborn
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df_balanced, x='high_sale', palette=['blue', 'orange'])
plt.xlabel('High Sales')
plt.ylabel('Count')
plt.title('Count of High Sales (0s and 1s)')
plt.show()
# Out:
# <ipython-input-15-3d03cad673d4>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_balanced, x='high_sale', palette=['blue', 'orange'])

# %%
df_balanced.head()
# Out:
#                                                title  \
# 0  Womens Summer Fashion Lip Print 2pc Set Ladies...
# 1  Shorts d'été pour femmes à lacets taille élast...
# 2  Women's Sexy Push Up Bikini Sexy Vintage Set S...
# 3  New Summer Fashion Women Sleeveless " HIPPIE S...
# 4  Été Casual Sexy Halter Vest Femmes Sac BuckleT...
#
#                                           title_orig  price  retail_price  \
# 0  Womens Summer Fashion Lip Print 2pc Set Ladies...    5.0            51
# 1  Women Summer Shorts Lace Up Elastic Waistband ...    2.0             2
# 2  Women's Sexy Push Up Bikini Vintage Set Sexy B...   11.0            30
# 3  New Summer Fashion Women Sleeveless “ HIPPIE S...    6.0            33
# 4  Summer Casual Sexy Halter Vest Women Bag Buckl...    7.0             6
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR          10               0    5.00             0
# 1            EUR         100               1    2.92            12
# 2            EUR          10               0    5.00             0
# 3            EUR        5000               0    4.04           846
# 4            EUR        1000               0    4.16           129
#
#    rating_five_count  ...               merchant_id  \
# 0                NaN  ...  5d464a1ffdf7bc44ee933c65
# 1                2.0  ...  5b47ffa01e5bc91f3eea4f1f
# 2                NaN  ...  56025ed8293a5b2d24779bde
# 3              451.0  ...  5784d339e8aa8938977fefd0
# 4               72.0  ...  590d6c356815062709f1b06c
#
#    merchant_has_profile_picture  merchant_profile_picture  \
# 0                             0                       NaN
# 1                             0                       NaN
# 2                             0                       NaN
# 3                             0                       NaN
# 4                             0                       NaN
#
#                                        product_url  \
# 0  https://www.wish.com/c/5eb90ab5ad67f63678d15ed9
# 1  https://www.wish.com/c/5ecc8472fe429946b009900e
# 2  https://www.wish.com/c/573db9316b335c34ca0513b8
# 3  https://www.wish.com/c/5c3ff9c71b115c0802243181
# 4  https://www.wish.com/c/5cd68836e731f919b55e08e3
#
#                                      product_picture  \
# 0  https://contestimg.wish.com/api/webimage/5eb90...
# 1  https://contestimg.wish.com/api/webimage/5ecc8...
# 2  https://contestimg.wish.com/api/webimage/573db...
# 3  https://contestimg.wish.com/api/webimage/5c3ff...
# 4  https://contestimg.wish.com/api/webimage/5cd68...
#
#                  product_id   theme  crawl_month high_sale  \
# 0  5eb90ab5ad67f63678d15ed9  summer      2020-08         0
# 1  5ecc8472fe429946b009900e  summer      2020-08         0
# 2  573db9316b335c34ca0513b8  summer      2020-08         0
# 3  5c3ff9c71b115c0802243181  summer      2020-08         1
# 4  5cd68836e731f919b55e08e3  summer      2020-08         1
#
#                                          image_pixel
# 0  [[[255.0, 255.0, 255.0], [255.0, 255.0, 255.0]...
# 1  [[[251.0, 245.0, 247.0], [251.0, 245.0, 247.0]...
# 2  [[[220.0, 222.0, 209.0], [221.0, 223.0, 210.0]...
# 3  [[[176.0, 176.0, 168.0], [176.0, 176.0, 168.0]...
# 4  [[[255.0, 255.0, 255.0], [255.0, 255.0, 255.0]...
#
# [5 rows x 45 columns]

# %%
df_balanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1582 entries, 0 to 1581
# Data columns (total 45 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1582 non-null   object
#  1   title_orig                    1582 non-null   object
#  2   price                         1582 non-null   float64
#  3   retail_price                  1582 non-null   int64
#  4   currency_buyer                1582 non-null   object
#  5   units_sold                    1582 non-null   int64
#  6   uses_ad_boosts                1582 non-null   int64
#  7   rating                        1582 non-null   float64
#  8   rating_count                  1582 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
#  12  rating_two_count              1528 non-null   float64
#  13  rating_one_count              1528 non-null   float64
#  14  badges_count                  1582 non-null   int64
#  15  badge_local_product           1582 non-null   int64
#  16  badge_product_quality         1582 non-null   int64
#  17  badge_fast_shipping           1582 non-null   int64
#  18  tags                          1582 non-null   object
#  19  product_color                 1537 non-null   object
#  20  product_variation_size_id     1572 non-null   object
#  21  product_variation_inventory   1582 non-null   int64
#  22  shipping_option_name          1582 non-null   object
#  23  shipping_option_price         1582 non-null   int64
#  24  shipping_is_express           1582 non-null   int64
#  25  countries_shipped_to          1582 non-null   int64
#  26  inventory_total               1582 non-null   int64
#  27  has_urgency_banner            497 non-null    float64
#  28  urgency_text                  497 non-null    object
#  29  origin_country                1565 non-null   object
#  30  merchant_title                1582 non-null   object
#  31  merchant_name                 1574 non-null   object
#  32  merchant_info_subtitle        1582 non-null   object
#  33  merchant_rating_count         1582 non-null   int64
#  34  merchant_rating               1582 non-null   float64
#  35  merchant_id                   1582 non-null   object
#  36  merchant_has_profile_picture  1582 non-null   int64
#  37  merchant_profile_picture      228 non-null    object
#  38  product_url                   1582 non-null   object
#  39  product_picture               1582 non-null   object
#  40  product_id                    1582 non-null   object
#  41  theme                         1582 non-null   object
#  42  crawl_month                   1582 non-null   object
#  43  high_sale                     1582 non-null   int64
#  44  image_pixel                   1582 non-null   object
# dtypes: float64(9), int64(16), object(20)
# memory usage: 556.3+ KB

# %%
def process_sentence(sentence):
    new_tokens = word_tokenize(sentence)
    new_tokens = [token.lower() for token in new_tokens]
    new_tokens =[token for token in new_tokens if token not in stopwords.words('english')]
    new_tokens = [token for token in new_tokens if token.isalpha()]
    lemmatizer = WordNetLemmatizer()
    new_tokens =[lemmatizer.lemmatize(token) for token in new_tokens]
    return "".join(new_tokens)

# %%
titles = df_balanced['title_orig'].tolist()
tokens = [process_sentence(t) for t in titles]
df_balanced['title_preprocessed'] = tokens
df_balanced.head()
# Out:
#                                                title  \
# 0  Womens Summer Fashion Lip Print 2pc Set Ladies...
# 1  Shorts d'été pour femmes à lacets taille élast...
# 2  Women's Sexy Push Up Bikini Sexy Vintage Set S...
# 3  New Summer Fashion Women Sleeveless " HIPPIE S...
# 4  Été Casual Sexy Halter Vest Femmes Sac BuckleT...
#
#                                           title_orig  price  retail_price  \
# 0  Womens Summer Fashion Lip Print 2pc Set Ladies...    5.0            51
# 1  Women Summer Shorts Lace Up Elastic Waistband ...    2.0             2
# 2  Women's Sexy Push Up Bikini Vintage Set Sexy B...   11.0            30
# 3  New Summer Fashion Women Sleeveless “ HIPPIE S...    6.0            33
# 4  Summer Casual Sexy Halter Vest Women Bag Buckl...    7.0             6
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR          10               0    5.00             0
# 1            EUR         100               1    2.92            12
# 2            EUR          10               0    5.00             0
# 3            EUR        5000               0    4.04           846
# 4            EUR        1000               0    4.16           129
#
#    rating_five_count  ...  merchant_has_profile_picture  \
# 0                NaN  ...                             0
# 1                2.0  ...                             0
# 2                NaN  ...                             0
# 3              451.0  ...                             0
# 4               72.0  ...                             0
#
#    merchant_profile_picture                                      product_url  \
# 0                       NaN  https://www.wish.com/c/5eb90ab5ad67f63678d15ed9
# 1                       NaN  https://www.wish.com/c/5ecc8472fe429946b009900e
# 2                       NaN  https://www.wish.com/c/573db9316b335c34ca0513b8
# 3                       NaN  https://www.wish.com/c/5c3ff9c71b115c0802243181
# 4                       NaN  https://www.wish.com/c/5cd68836e731f919b55e08e3
#
#                                      product_picture  \
# 0  https://contestimg.wish.com/api/webimage/5eb90...
# 1  https://contestimg.wish.com/api/webimage/5ecc8...
# 2  https://contestimg.wish.com/api/webimage/573db...
# 3  https://contestimg.wish.com/api/webimage/5c3ff...
# 4  https://contestimg.wish.com/api/webimage/5cd68...
#
#                  product_id   theme  crawl_month  high_sale  \
# 0  5eb90ab5ad67f63678d15ed9  summer      2020-08          0
# 1  5ecc8472fe429946b009900e  summer      2020-08          0
# 2  573db9316b335c34ca0513b8  summer      2020-08          0
# 3  5c3ff9c71b115c0802243181  summer      2020-08          1
# 4  5cd68836e731f919b55e08e3  summer      2020-08          1
#
#                                          image_pixel  \
# 0  [[[255.0, 255.0, 255.0], [255.0, 255.0, 255.0]...
# 1  [[[251.0, 245.0, 247.0], [251.0, 245.0, 247.0]...
# 2  [[[220.0, 222.0, 209.0], [221.0, 223.0, 210.0]...
# 3  [[[176.0, 176.0, 168.0], [176.0, 176.0, 168.0]...
# 4  [[[255.0, 255.0, 255.0], [255.0, 255.0, 255.0]...
#
#                                   title_preprocessed
# 0  womenssummerfashionlipprintsetladycasualroundn...
# 1  womansummershortlaceelasticwaistbandloosepanty...
# 2  womansexypushbikinivintagesetsexybrazilianbiquini
# 3  newsummerfashionwomansleevelesshippiesoullette...
# 4  summercasualsexyhaltervestwomanbagbuckletankto...
#
# [5 rows x 46 columns]

# %%
from transformers import BertTokenizer, TFBertModel
# Initialize tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = TFBertModel.from_pretrained('bert-base-uncased')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
from transformers import BertTokenizer, TFBertModel
import tensorflow as tf
import numpy as np
import warnings

# Suppress warnings
warnings.filterwarnings('ignore')

# Initialize BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', from_pt=True)
bert_model = TFBertModel.from_pretrained('bert-base-uncased', from_pt=True)

def encode_texts(texts, max_length=128):
    inputs = tokenizer(
        texts.tolist(),
        max_length=max_length,
        padding='max_length',
        truncation=True,
        return_tensors="tf"
    )
    return inputs

def get_bert_embeddings(encoded_inputs):
    outputs = bert_model(encoded_inputs['input_ids'],
                        attention_mask=encoded_inputs['attention_mask'])
    return outputs.last_hidden_state[:, 0, :]

def process_in_batches(df, batch_size=32):
    all_embeddings = []

    # Calculate number of batches
    n_samples = len(df_balanced)
    n_batches = (n_samples + batch_size - 1) // batch_size

    for i in range(n_batches):
        start_idx = i * batch_size
        end_idx = min((i + 1) * batch_size, n_samples)

        # Get batch of texts
        batch_texts = df_balanced['title_preprocessed'].iloc[start_idx:end_idx]

        # Process batch
        batch_encodings = encode_texts(batch_texts)
        batch_embeddings = get_bert_embeddings(batch_encodings)

        # Convert to numpy and store
        all_embeddings.append(batch_embeddings.numpy())

        print(f"Processed batch {i+1}/{n_batches}", end='\r')

    # Combine all batches
    final_embeddings = np.vstack(all_embeddings)
    print("\nProcessing complete!")
    return final_embeddings

# Process data in batches
bert_embeddings_np = process_in_batches(df_balanced, batch_size=32)

print("BERT embeddings shape:", bert_embeddings_np.shape)

# Add embeddings as features
for i in range(bert_embeddings_np.shape[1]):
    df_balanced[f'bert_feature_{i}'] = bert_embeddings_np[:, i]
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# Processed batch 50/50
# Processing complete!
# BERT embeddings shape: (1582, 768)

# %%
df_balanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1582 entries, 0 to 1581
# Columns: 814 entries, title to bert_feature_767
# dtypes: float32(768), float64(9), int64(16), object(21)
# memory usage: 5.2+ MB

# %%
X = df_balanced['image_pixel']
y = df_balanced['high_sale']

# %%
# Loop over column names and assign them to X
for i in range(768):  # Since there are 768 BERT features
    X[f'bert_feature_{i}'] = df_balanced[f'bert_feature_{i}']

# %%
X.shape
# Out:
# (2350,)

# %%
y.shape
# Out:
# (1582,)

# %%
def create_combined_model(input_shape_image, input_shape_bert):
    # Input layers
    image_input = Input(shape=input_shape_image, name='image_input')
    bert_input = Input(shape=(input_shape_bert,), name='bert_input')

    # Image processing branch - increased capacity
    base_model = EfficientNetB5(weights='imagenet',
                               include_top=False,
                               input_shape=input_shape_image)

    # Freeze fewer layers (70%) to allow more learning
    for layer in base_model.layers[:int(0.7 * len(base_model.layers))]:
        layer.trainable = False

    image_x = base_model(image_input)
    image_x = GlobalAveragePooling2D()(image_x)
    image_x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(image_x)
    image_x = BatchNormalization()(image_x)
    image_x = Dropout(0.3)(image_x)

    # BERT features processing - deeper network
    bert_x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(bert_input)
    bert_x = BatchNormalization()(bert_x)
    bert_x = Dropout(0.3)(bert_x)

    bert_x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(bert_x)
    bert_x = BatchNormalization()(bert_x)
    bert_x = Dropout(0.2)(bert_x)

    # Combine features with attention mechanism
    combined = Concatenate()([image_x, bert_x])

    # Deeper fusion layers
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(combined)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    output = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=[image_input, bert_input], outputs=output)

    optimizer = Adam(learning_rate=1e-4)

    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB5
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import tensorflow as tf
from keras import Input

bert_features = [f'bert_feature_{i}' for i in range(768)]

# Prepare all data types
X_bert = df_balanced[bert_features].values
X_image = np.stack(df_balanced['image_pixel'].values)
y = df_balanced['high_sale'].values

# Normalize image data
X_image = X_image / 255.0

# Split data maintaining alignment
X_image_train, X_image_test, X_bert_train, X_bert_test, y_train, y_test = train_test_split(
    X_image, X_bert, y, test_size=0.125, random_state=42
)

X_image_train, X_image_val, X_bert_train, X_bert_val, y_train, y_val = train_test_split(
    X_image_train, X_bert_train, y_train, test_size=0.14286, random_state=42
)

# Create and train model
input_shape_image = X_image.shape[1:]
model = create_combined_model(
    input_shape_image=input_shape_image,
    input_shape_bert=768,
)

# %%
from sklearn.utils.class_weight import compute_class_weight

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=10,
        restore_best_weights=True,
        min_delta=0.001
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    )
]

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weight_dict = dict(enumerate(class_weights))

# Training with modified parameters
history = model.fit(
    [X_image_train, X_bert_train],
    y_train,
    validation_data=([X_image_val, X_bert_val], y_val),
    epochs=50,
    batch_size=32,
    callbacks=callbacks,
    class_weight=class_weight_dict,
    verbose=1
)
# Out:
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 241s 3s/step - accuracy: 0.5119 - loss: 3.2225 - val_accuracy: 0.4949 - val_loss: 2.9911 - learning_rate: 1.0000e-04
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 21s 233ms/step - accuracy: 0.5136 - loss: 3.2104 - val_accuracy: 0.5152 - val_loss: 2.9699 - learning_rate: 1.0000e-04
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 220ms/step - accuracy: 0.5140 - loss: 3.1738 - val_accuracy: 0.4899 - val_loss: 2.9549 - learning_rate: 1.0000e-04
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 230ms/step - accuracy: 0.5378 - loss: 3.0980 - val_accuracy: 0.4949 - val_loss: 2.9333 - learning_rate: 1.0000e-04
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.5709 - loss: 3.0248 - val_accuracy: 0.5859 - val_loss: 2.9057 - learning_rate: 1.0000e-04
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 0.5395 - loss: 3.0894 - val_accuracy: 0.5758 - val_loss: 2.8895 - learning_rate: 1.0000e-04
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 236ms/step - accuracy: 0.5866 - loss: 2.9875 - val_accuracy: 0.6061 - val_loss: 2.8833 - learning_rate: 1.0000e-04
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 246ms/step - accuracy: 0.5610 - loss: 2.9923 - val_accuracy: 0.5505 - val_loss: 2.8720 - learning_rate: 1.0000e-04
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 232ms/step - accuracy: 0.5849 - loss: 2.9220 - val_accuracy: 0.5000 - val_loss: 2.8780 - learning_rate: 1.0000e-04
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 228ms/step - accuracy: 0.5758 - loss: 2.9462 - val_accuracy: 0.4949 - val_loss: 2.8937 - learning_rate: 1.0000e-04
# Epoch 11/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 231ms/step - accuracy: 0.5644 - loss: 2.9317 - val_accuracy: 0.5606 - val_loss: 2.8493 - learning_rate: 1.0000e-04
# Epoch 12/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.5586 - loss: 2.9447
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 0.5589 - loss: 2.9444 - val_accuracy: 0.5808 - val_loss: 2.8442 - learning_rate: 1.0000e-04
# Epoch 13/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 227ms/step - accuracy: 0.5483 - loss: 2.9415 - val_accuracy: 0.5859 - val_loss: 2.8373 - learning_rate: 5.0000e-05
# Epoch 14/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 227ms/step - accuracy: 0.5558 - loss: 2.9307 - val_accuracy: 0.5960 - val_loss: 2.8319 - learning_rate: 5.0000e-05
# Epoch 15/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 236ms/step - accuracy: 0.5762 - loss: 2.9116 - val_accuracy: 0.5758 - val_loss: 2.8310 - learning_rate: 5.0000e-05
# Epoch 16/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 258ms/step - accuracy: 0.5696 - loss: 2.9259 - val_accuracy: 0.6111 - val_loss: 2.8219 - learning_rate: 5.0000e-05
# Epoch 17/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 230ms/step - accuracy: 0.5629 - loss: 2.9019 - val_accuracy: 0.5758 - val_loss: 2.8342 - learning_rate: 5.0000e-05
# Epoch 18/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 248ms/step - accuracy: 0.5909 - loss: 2.8778 - val_accuracy: 0.5758 - val_loss: 2.8255 - learning_rate: 5.0000e-05
# Epoch 19/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 250ms/step - accuracy: 0.5837 - loss: 2.8867 - val_accuracy: 0.5657 - val_loss: 2.8092 - learning_rate: 5.0000e-05
# Epoch 20/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 245ms/step - accuracy: 0.5526 - loss: 2.8980 - val_accuracy: 0.5960 - val_loss: 2.7992 - learning_rate: 5.0000e-05
# Epoch 21/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 240ms/step - accuracy: 0.5697 - loss: 2.8853 - val_accuracy: 0.6313 - val_loss: 2.7896 - learning_rate: 5.0000e-05
# Epoch 22/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 236ms/step - accuracy: 0.5877 - loss: 2.8672 - val_accuracy: 0.6010 - val_loss: 2.7960 - learning_rate: 5.0000e-05
# Epoch 23/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 0.6246 - loss: 2.8427 - val_accuracy: 0.6061 - val_loss: 2.8014 - learning_rate: 5.0000e-05
# Epoch 24/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 253ms/step - accuracy: 0.6506 - loss: 2.8244 - val_accuracy: 0.6515 - val_loss: 2.7847 - learning_rate: 5.0000e-05
# Epoch 25/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 247ms/step - accuracy: 0.6295 - loss: 2.8198 - val_accuracy: 0.6010 - val_loss: 2.7848 - learning_rate: 5.0000e-05
# Epoch 26/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 237ms/step - accuracy: 0.6202 - loss: 2.8099 - val_accuracy: 0.6111 - val_loss: 2.7717 - learning_rate: 5.0000e-05
# Epoch 27/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 232ms/step - accuracy: 0.6133 - loss: 2.8356 - val_accuracy: 0.6162 - val_loss: 2.7625 - learning_rate: 5.0000e-05
# Epoch 28/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step - accuracy: 0.5865 - loss: 2.8485 - val_accuracy: 0.6061 - val_loss: 2.7630 - learning_rate: 5.0000e-05
# Epoch 29/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.5960 - loss: 2.8441
# Epoch 29: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 248ms/step - accuracy: 0.5961 - loss: 2.8443 - val_accuracy: 0.6111 - val_loss: 2.7527 - learning_rate: 5.0000e-05
# Epoch 30/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 238ms/step - accuracy: 0.5951 - loss: 2.8493 - val_accuracy: 0.6212 - val_loss: 2.7539 - learning_rate: 2.5000e-05
# Epoch 31/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 233ms/step - accuracy: 0.6088 - loss: 2.8077 - val_accuracy: 0.6313 - val_loss: 2.7500 - learning_rate: 2.5000e-05
# Epoch 32/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 236ms/step - accuracy: 0.6266 - loss: 2.7890 - val_accuracy: 0.6515 - val_loss: 2.7463 - learning_rate: 2.5000e-05
# Epoch 33/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 260ms/step - accuracy: 0.5819 - loss: 2.8197 - val_accuracy: 0.6566 - val_loss: 2.7480 - learning_rate: 2.5000e-05
# Epoch 34/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 250ms/step - accuracy: 0.5967 - loss: 2.8193 - val_accuracy: 0.6465 - val_loss: 2.7509 - learning_rate: 2.5000e-05
# Epoch 35/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 0.6125 - loss: 2.8001 - val_accuracy: 0.6414 - val_loss: 2.7524 - learning_rate: 2.5000e-05
# Epoch 36/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 241ms/step - accuracy: 0.5987 - loss: 2.8224 - val_accuracy: 0.6313 - val_loss: 2.7569 - learning_rate: 2.5000e-05
# Epoch 37/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 249ms/step - accuracy: 0.5804 - loss: 2.8531 - val_accuracy: 0.6566 - val_loss: 2.7524 - learning_rate: 2.5000e-05
# Epoch 38/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 239ms/step - accuracy: 0.5977 - loss: 2.8085 - val_accuracy: 0.6869 - val_loss: 2.7474 - learning_rate: 2.5000e-05
# Epoch 39/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 239ms/step - accuracy: 0.6367 - loss: 2.7647 - val_accuracy: 0.6414 - val_loss: 2.7478 - learning_rate: 2.5000e-05
# Epoch 40/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 249ms/step - accuracy: 0.6153 - loss: 2.7759 - val_accuracy: 0.6414 - val_loss: 2.7498 - learning_rate: 2.5000e-05
# Epoch 41/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 233ms/step - accuracy: 0.6101 - loss: 2.7789 - val_accuracy: 0.6111 - val_loss: 2.7581 - learning_rate: 2.5000e-05
# Epoch 42/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 237ms/step - accuracy: 0.6138 - loss: 2.7873 - val_accuracy: 0.6313 - val_loss: 2.7460 - learning_rate: 2.5000e-05
# Epoch 43/50
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.6533 - loss: 2.7829
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 239ms/step - accuracy: 0.6524 - loss: 2.7832 - val_accuracy: 0.6313 - val_loss: 2.7440 - learning_rate: 2.5000e-05
# Epoch 44/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 237ms/step - accuracy: 0.5855 - loss: 2.8217 - val_accuracy: 0.6313 - val_loss: 2.7444 - learning_rate: 1.2500e-05
# Epoch 45/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 11s 247ms/step - accuracy: 0.6403 - loss: 2.7531 - val_accuracy: 0.6414 - val_loss: 2.7439 - learning_rate: 1.2500e-05
# Epoch 46/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 253ms/step - accuracy: 0.6032 - loss: 2.8098 - val_accuracy: 0.6465 - val_loss: 2.7433 - learning_rate: 1.2500e-05
# Epoch 47/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 241ms/step - accuracy: 0.6257 - loss: 2.7879 - val_accuracy: 0.6313 - val_loss: 2.7443 - learning_rate: 1.2500e-05
# Epoch 48/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.6280 - loss: 2.7703
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 246ms/step - accuracy: 0.6279 - loss: 2.7708 - val_accuracy: 0.6313 - val_loss: 2.7466 - learning_rate: 1.2500e-05

# %%
# Plot training history
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import accuracy_score
import numpy as np

# Predict on the test data
y_pred_prob = model.predict([X_image_test, X_bert_test])

# Convert probabilities to binary predictions (threshold 0.5 for sigmoid activation)
y_pred = (y_pred_prob >= 0.5).astype(int).flatten()

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy on test data: {accuracy:.2f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step
# Accuracy on test data: 0.65
